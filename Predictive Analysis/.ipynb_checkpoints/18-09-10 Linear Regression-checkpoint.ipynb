# %% [markdown]
# # Linear Regression
#
# <span>Below is an example of a regression problem using linear regression to predict house prices from a dataset provided on Kaggle. The dataset can be found at the link below. Note that I have tried to reduce the amount of regularization found in sklearn's implementation of the model. As well as attempting to compare and contrast the performance of both statsmodel's linear regression model and sklearn's linear regression model. I try to avoid a lot of feature engineering here, as this notebook is just an example of the models.</span>
#
# ### Import Preliminaries

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# Import modules
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import numpy as np
import pandas as pd 
import seaborn as sns
import statsmodels.api as sm
import warnings

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from statsmodels.regression import linear_model


# Import models
from sklearn.linear_model import LinearRegression

# Set pandas options
pd.set_option('max_columns',1000)
pd.set_option('max_rows',100)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set plotting options
mpl.rcParams['figure.figsize'] = (8.0, 7.0)

# Set warning options
warnings.filterwarnings('ignore');

# Configured summmary statistic functions
def sum_stat(df):
    df = pd.concat([df.describe(), 
           pd.DataFrame(df.nunique(), columns=['nuniques']).T,
           pd.DataFrame(np.sum(df.isnull(), axis =0), columns=['isnull']).T],
           axis=0)
    return df

# %% [markdown]
# ### Import Data

# %%
# Import data
test_df = pd.read_csv('Data/Home Prices/test.csv')
train_df = pd.read_csv('Data/Home Prices/train.csv')

# Create a list of dataframe
dfs = [train_df, test_df]

# Lower columns names in dataframes
for df in dfs:
    df.columns = df.columns.str.lower()

# Rename target feature
train_df = train_df.rename(columns={'saleprice':'target'})

# Print dataframe shapes
print(f'Training DataFrame:  {train_df.shape}')
print(f'Testing DataFrame:  {test_df.shape}')
# Out:
# Training DataFrame:  (1460, 81)
# Testing DataFrame:  (1459, 80)

# %% [markdown]
# ### Target Outcomes

# %%
# Plot a histogram of all the home price valuse
train_df.target.hist(grid=False, color='#5C3697', edgecolor='w',)
plt.title('Distribution of Sales Prices Outcomes')
plt.ylabel('Frequency')
plt.xlabel('SalesPrice')
plt.axvline(train_df.target.mean(), color='black', linestyle='dashed', linewidth=2);

# %% [markdown]
# ### Viewing Null Values

# %%
# View number of null values in object feature
null_obj_train_df = train_df.select_dtypes(include='object')
null_obj_train_df = null_obj_train_df.isnull().sum().to_frame(name='null_values')
null_obj_train_df = null_obj_train_df[null_obj_train_df.null_values > 0]
null_obj_train_df
# Out:
#               null_values
# alley                1369
# masvnrtype              8
# bsmtqual               37
# bsmtcond               37
# bsmtexposure           38
# bsmtfintype1           37
# bsmtfintype2           38
# electrical              1
# fireplacequ           690
# garagetype             81
# garagefinish           81
# garagequal             81
# garagecond             81
# poolqc               1453
# fence                1179
# miscfeature          1406

# %%
# View the number of null feature in the numeric features
null_num_train_df = train_df.select_dtypes(exclude='object')
null_num_train_df = null_num_train_df.isnull().sum().to_frame(name='null_values')
null_num_train_df = null_num_train_df[null_num_train_df.null_values > 0]
null_num_train_df
# Out:
#              null_values
# lotfrontage          259
# masvnrarea             8
# garageyrblt           81

# %%
# View numerical feature with null values to confirm if all
# values are continuous
train_df[null_num_train_df.index].mean()
# Out:
# lotfrontage     70.050
# masvnrarea     103.685
# garageyrblt   1978.506
# dtype: float64

# %% [markdown]
# It seems that we have wide range of null valuse for each feature in our datasets. For this example, I will quickly go through each feature and a replace any missing categorical value with the value 'Unknown" and replace any missing categorical valuse with the mean. This will let us quickly clearn the data so we can go on and move onto our linear regression model.

# %%
# Fill null numerical valuse with their meann
for col in null_num_train_df.index:
    train_df[col].fillna(value = train_df[col].mean(), inplace=True)

# FIll null categorical valuse with unknown
for col in null_obj_train_df.index:
    train_df[col].fillna(value = 'Unknown', inplace=True)

# %%
# Plot feature correlation via a seaborn heatmap
sns.heatmap(train_df.corr(), cmap=plt.cm.Purples);
plt.title('Feature Correlation Matrix');
plt.xlabel('Features')
plt.ylabel('Features');

# %% [markdown]
# ### Preprocessing Data

# %%
# One-hot encode all non-ordinal categorical data
train_df = pd.get_dummies(train_df)

# %% [markdown]
# ### Encoding Data

# %%
# Change dataframe to numpy array 
y = train_df.target.values
X = train_df.drop('target', axis=1).values

# Conduct a train-test-split on the data
train_x, test_x, train_y, test_y = train_test_split(X,y, test_size=0.25)

# %% [markdown]
# ### Linear Regression

# %%
# Fit a linear model
lr_model = LinearRegression()
lr_model.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Calculate our cross validation score
cross_val_score(lr_model, train_x, train_y, cv=5, 
                scoring='neg_mean_squared_error').mean()
# Out:
# -1.2306116467894349e+18

# %% [markdown]
# Our cross validation score on our training set was pretty good, considering the best scores from Kaggle Competition competitors hovers around 80.

# %% [markdown]
# ### Viewing Residuals

# %%
# Plotting residuals from our model
pred_y = lr_model.predict(train_x)
sns.residplot(pred_y, train_y, color='#3F007D');
plt.title('Linear Model Residuals')
plt.ylabel('Price Difference')
plt.xlabel('Trainig Record')
# Out:
# Text(0.5,0,'Trainig Record')

# %% [markdown]
# ### Viewing the Coefficients

# %%
# Creating a dataframe of our coeffficients
coef_names = pd.Series(train_df.drop('target', axis=1).columns, name='feature')
coefs = pd.Series(lr_model.coef_, name='coef')
pd.concat([coef_names, coefs],axis=1).sort_values(by='coef', ascending=False)
# Out:
#                    feature        coef
# 279         poolqc_Unknown  300395.396
# 128       roofmatl_Membran  150671.784
# 129         roofmatl_Metal  118984.233
# 261          garagequal_Ex  111879.146
# 133       roofmatl_WdShngl  105518.572
# 125         roofstyle_Shed   67264.958
# 127       roofmatl_CompShg   59504.658
# 132       roofmatl_WdShake   47441.434
# 131       roofmatl_Tar&Grv   46959.599
# 192            bsmtcond_Po   40449.343
# 286       miscfeature_Othr   38779.466
# 102        condition2_PosA   37971.408
# 87    neighborhood_StoneBr   37830.822
# 288       miscfeature_TenC   36229.135
# 130          roofmatl_Roll   34427.406
# 296           saletype_New   28892.868
# 291           saletype_CWD   28615.214
# 183       foundation_Stone   27096.823
# 271          garagecond_TA   25054.287
# 80    neighborhood_NoRidge   24215.432
# 268          garagecond_Fa   24129.689
# 219           heating_Wall   21905.603
# 71    neighborhood_Crawfor   21193.268
# 78    neighborhood_NPkVill   20873.435
# 269          garagecond_Gd   19568.582
# 66    neighborhood_Blueste   19528.710
# 300  salecondition_AdjLand   18789.271
# 243         functional_Typ   18485.539
# 196        bsmtexposure_Gd   17610.739
# 63           landslope_Mod   16962.196
# 233         kitchenqual_Ex   15830.404
# 270          garagecond_Po   15621.183
# 55        utilities_AllPub   15176.841
# 106        condition2_RRNn   14876.305
# 93         condition1_PosA   14854.246
# 137    exterior1st_BrkFace   14607.657
# 228       electrical_FuseF   14468.318
# 170           exterqual_Ex   13477.408
# 232     electrical_Unknown   12724.138
# 181       foundation_PConc   12599.568
# 162    exterior2nd_VinylSd   12538.995
# 238        functional_Maj2   12492.455
# 113      housestyle_1.5Unf   11957.960
# 292           saletype_Con   11909.927
# 180      foundation_CBlock   11812.292
# 168       masvnrtype_Stone   11585.579
# 134    exterior1st_AsbShng   11506.125
# 150    exterior2nd_AsphShn   11319.299
# 179      foundation_BrkTil   11218.425
# 289    miscfeature_Unknown   11153.793
# ..                     ...         ...
# 141    exterior1st_ImStucc  -11569.794
# 124      roofstyle_Mansard  -11594.429
# 122      roofstyle_Gambrel  -11893.178
# 169     masvnrtype_Unknown  -11970.573
# 199   bsmtexposure_Unknown  -12365.492
# 121        roofstyle_Gable  -12557.129
# 77      neighborhood_NAmes  -12656.881
# 123          roofstyle_Hip  -12901.297
# 187            bsmtqual_Gd  -13069.471
# 88     neighborhood_Timber  -13088.272
# 160      exterior2nd_Stone  -13595.745
# 294         saletype_ConLI  -14504.429
# 56        utilities_NoSeWa  -15176.841
# 213   bsmtfintype2_Unknown  -15417.236
# 298            saletype_WD  -15680.445
# 250      garagetype_2Types  -15748.892
# 193            bsmtcond_TA  -16393.576
# 295         saletype_ConLw  -16498.371
# 214          heating_Floor  -16587.815
# 190            bsmtcond_Fa  -16845.132
# 22            kitchenabvgr  -16993.705
# 79     neighborhood_NWAmes  -17155.023
# 290           saletype_COD  -17578.908
# 69    neighborhood_ClearCr  -17904.785
# 191            bsmtcond_Gd  -18297.149
# 120         roofstyle_Flat  -18318.925
# 72    neighborhood_Edwards  -18571.597
# 76    neighborhood_Mitchel  -20048.964
# 158      exterior2nd_Other  -20361.845
# 265          garagequal_TA  -21066.134
# 95         condition1_RRAe  -21284.326
# 115      housestyle_2.5Fin  -21300.161
# 304  salecondition_Partial  -22091.478
# 97         condition1_RRNe  -23518.869
# 263          garagequal_Gd  -24222.734
# 64           landslope_Sev  -25878.632
# 37        mszoning_C (all)  -27176.947
# 135    exterior1st_AsphShn  -27319.861
# 262          garagequal_Fa  -27998.716
# 218           heating_OthW  -28714.498
# 230         electrical_Mix  -31716.917
# 242         functional_Sev  -34887.865
# 103        condition2_PosN  -37886.985
# 264          garagequal_Po  -40873.390
# 184        foundation_Wood  -60975.639
# 267          garagecond_Ex  -86655.570
# 285       miscfeature_Gar2  -96421.729
# 278              poolqc_Gd -126300.974
# 277              poolqc_Fa -166075.559
# 126       roofmatl_ClyTile -563507.688
#
# [305 rows x 2 columns]

# %% [markdown]
# ### Using Stat Models
#
# Using thest stats models can give us a bit more information about the linear regression then sklearn. So lets give it a try.

# %%
# Conduct linear regression via stats model's API
myregression = linear_model.OLS(train_y, train_x).fit()
myregression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0