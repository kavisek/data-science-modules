# %% [markdown]
# # DBSCAN
#
# <span>DBSCAN stands for density-based spatial clustering of applications with noise. The algorithim select random points on the hyperplane and if the points is connected to greater than n points within a defined disctance, the algorithim defines the points a a core sample. If the point is not a core sample it is defined as Noise. Then another point is chosen by the algorithim. Once all the point are marked as sample or noise the algorithim stops.</span>

# %% [markdown]
# ### Import Preliminaries

# %%
# %matplotlib inline
# %pylab inline
 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import sklearn
import seaborn
import warnings
from sklearn.cluster import DBSCAN
 
pd.set_option('max_columns',1000)
pd.set_option('max_rows',30)
 
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pylab.rcParams['figure.figsize'] = (8.0, 7.0)
warnings.filterwarnings('ignore');
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Import Data

# %%
# %matplotlib inline
import seaborn as sns
import numpy as np
iris = sns.load_dataset("iris")


from sklearn.cluster import DBSCAN

db = DBSCAN(eps=0.8, min_samples=5).fit(iris.iloc[:,:4])
#try this out with a range of eps and min_samples

# %% [markdown]
# ### View Labels

# %%
pd.Series(db.labels_ ).sample(10)
# Out:
# 139    1
# 136    1
# 78     1
# 66     1
# 99     1
# 21     0
# 35     0
# 45     0
# 137    1
# 140    1
# dtype: int64

# %%
### View Cores
pd.Series(db.core_sample_indices_).sample(10)
# Out:
# 116    119
# 60      60
# 123    126
# 113    114
# 25      25
# 92      92
# 8        8
# 26      26
# 138    142
# 119    122
# dtype: int64

# %%
print(db.core_sample_indices_) #cores

# %%
# 4 Dimensions datafarme clustered on 2 dataframes, these are not the best plots
for index, eps in enumerate([0.25, 0.5, 0.75, 1, 5]):
    model = DBSCAN(eps = eps, min_samples = 8)
    model.fit(iris.iloc[:,:4].values)
    fig = plt.figure()
    print(f'number of noise points: {np.sum(model.labels_ < 0)}')
    plt.scatter(iris.iloc[:,0].values, iris.iloc[:,1].values, c = model.labels_,);
# Out:
# number of noise points: 126
# number of noise points: 26
# number of noise points: 4
# number of noise points: 0
# number of noise points: 0

# %% [markdown]
# Author: Kavi Sekhon
