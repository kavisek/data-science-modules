# %% [markdown]
# # Convolutional Neural Network - Regression
# ### Import Preliminaries

# %%
import numpy as np
from keras import models
from keras import layers
from keras.datasets import boston_housing
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-886bb347f6ee> in <module>()
#       1 import numpy as np
# ----> 2 from keras import models
#       3 from keras import layers
#       4 from keras.datasets import boston_housing
#
# ~/anaconda/lib/python3.6/site-packages/keras/__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~/anaconda/lib/python3.6/site-packages/keras/utils/__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# ~/anaconda/lib/python3.6/site-packages/keras/utils/conv_utils.py in <module>()
#       1 from six.moves import range
#       2 import numpy as np
# ----> 3 from .. import backend as K
#       4
#       5
#
# ~/anaconda/lib/python3.6/site-packages/keras/backend/__init__.py in <module>()
#      81 elif _BACKEND == 'tensorflow':
#      82     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 83     from .tensorflow_backend import *
#      84 else:
#      85     raise ValueError('Unknown backend: ' + str(_BACKEND))
#
# ~/anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in <module>()
#       1 import tensorflow as tf
# ----> 2 from tensorflow.python.client import device_lib
#       3 from tensorflow.python.training import moving_averages
#       4 from tensorflow.python.ops import tensor_array_ops
#       5 from tensorflow.python.ops import control_flow_ops
#
# ModuleNotFoundError: No module named 'tensorflow.python.client'

# %% [markdown]
# ### Preprocessing the Data

# %%
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

# Normalize the data
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a91271a6fed6> in <module>()
# ----> 1 (train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
#       2
#       3 # Normalize the data
#       4 mean = train_data.mean(axis=0)
#       5 train_data -= mean
#
# NameError: name 'boston_housing' is not defined

# %% [markdown]
# ### Build Your Model

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1))

# %% [markdown]
# ### Compile Your Model

# %%
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ### Fit Your Model

# %%
# Fit Variables
num_epochs = 100


model.fit(train_data, train_targets,
             epochs=num_epochs, batch_size=1, verbose=0)


val_mse, val_mae = model.evaluate(test_data, test_targets, 
                                verbose=0)

# %% [markdown]
# ### View the Results

# %%
print('Mean Squared Error',val_mse)
print('Mean Absolute Error',val_mae)
# Out:
# Mean Squared Error 205.854730344
# Mean Absolute Error 10.1681109784
