# %% [markdown]
# # Using Linear Discriminant Analysis For Dimensionality Reduction
# ### Preliminaries

# %%
# Load libraries
from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# ### Load Iris Data

# %%
# Load the Iris flower dataset:
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ### Create A Linear

# %%
# Create a LDA that will reducet the data down to 1 feature
lda = LinearDiscriminantAnalysis(n_components=1)

# Run the LDA and use it to transform the features
X_lda = lda.fit(X, y).transform(X)

# %% [markdown]
# ### View the Results

# %%
# Print the number of features
print('Original number of features:', X.shape[1])
print('Reduced number of featurse:', X_lda.shape[1])
# Out:
# Original number of features: 4
# Reduced number of featurse: 1

# %% [markdown]
# ###  View Percentage Of Variance Retained By New Features

# %%
# View the ration of explained variance 
lda.explained_variance_ratio_
# Out:
# array([ 0.99147248])

# %% [markdown]
# Source: https://chrisalbon.com/machine-learning/lda_for_dimensionality_reduction.html
