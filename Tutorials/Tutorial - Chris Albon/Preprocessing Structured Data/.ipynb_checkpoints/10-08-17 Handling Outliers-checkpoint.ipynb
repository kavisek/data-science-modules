# %% [markdown]
# # Handling Outliers
#
# Drop: Not a great option. We lose lots of information. Find ou if the genuine extreme value or broken sensor.
#
# Mark: Safest option. We can see if the outliers had an effect.
#
# Rescale: Log values os outiers don't have as great an effect
#
# ### Preliminaries

# %%
# Load library
import pandas as pd

# %% [markdown]
# ### Create Data

# %%
# Create DataFrame
houses = pd.DataFrame()
houses['Price'] = [534433, 392333, 293222, 4322032]
houses['Bathrooms'] = [2, 3.5, 2, 116]
houses['Square_Feet'] = [1500, 2500, 1500, 48000]

houses
# Out:
#      Price  Bathrooms  Square_Feet
# 0   534433        2.0         1500
# 1   392333        3.5         2500
# 2   293222        2.0         1500
# 3  4322032      116.0        48000

# %% [markdown]
# ### Option 1: Drop

# %%
# Drop observations greater than some value
houses[houses['Bathrooms'] < 20]
# Out:
#     Price  Bathrooms  Square_Feet
# 0  534433        2.0         1500
# 1  392333        3.5         2500
# 2  293222        2.0         1500

# %% [markdown]
# ### Option 2: Mark

# %%
# Load library
import numpy as np

# Create feature based on boolean condition
houses['Outlier'] = np.where(houses['Bathrooms'] < 20, 0, 1)

# Show Data
houses
# Out:
#      Price  Bathrooms  Square_Feet  Outlier
# 0   534433        2.0         1500        0
# 1   392333        3.5         2500        0
# 2   293222        2.0         1500        0
# 3  4322032      116.0        48000        1

# %% [markdown]
# ### Option 3: Rescale

# %%
# Log feature
houses['Log_Of_Square_Feed'] = [np.log(x) for x in houses['Square_Feet']]

# Show data
houses
# Out:
#      Price  Bathrooms  Square_Feet  Outlier  Log_Of_Square_Feed
# 0   534433        2.0         1500        0            7.313220
# 1   392333        3.5         2500        0            7.824046
# 2   293222        2.0         1500        0            7.313220
# 3  4322032      116.0        48000        1           10.778956

# %% [markdown]
# Sources: https://chrisalbon.com/machine-learning/handling_outliers.html
