# %% [markdown]
# # Enhance Constrast Of Greyscale Image
# Source: https://chrisalbon.com/machine-learning/enhance_contrast_of_greyscale_image.html
# ### Preliminaries

# %%
# Load image
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load Image As Grayscale

# %%
# Load image as grayscale 
image = cv2.imread('images/plane_256x256.jpg', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# ### Enhance Image

# %%
# Enhance image
image_enhanced = cv2.equalizeHist(image)

# %% [markdown]
# ### View Image

# %%
# Show image
plt.imshow(image_enhanced, cmap='gray'), plt.axis("off")
plt.show()
