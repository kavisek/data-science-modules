# %% [markdown]
# # Sharpen Images
# Soucre: http://localhost:8888/notebooks/Dropbox/DataScience/Tutorials/Tutorial%20-%20Chris%20Albon/Preprocessing%20Images/10-27-17%20Sharpen%20Images.ipynb
# ### Preliminaries

# %%
# Load image
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load Images As Greyscale

# %%
# Load image as grayscale
image = cv2.imread('images/plane_256x256.jpg', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# ### Shargen Images

# %%
# Create kernel
kernel  = np.array([[0,-1,0],
                  [-1,5,-1],
                  [0,-1,0]])

# Sharpen image
image_sharp =  cv2.filter2D(image, -1, kernel)

# %% [markdown]
# ### View Image

# %%
# Show image
plt.imshow(image_sharp, cmap='gray'), plt.axis('off')
plt.show()
