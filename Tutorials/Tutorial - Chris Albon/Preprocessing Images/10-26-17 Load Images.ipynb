# %% [markdown]
# # Load Images
# Source: https://chrisalbon.com/machine-learning/load_images.html
# ### Preliminaries

# %%
# Load library
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load Image As Grayscale

# %%
# Load image in color
image = cv2.imread('images/plane.jpg', cv2.IMREAD_COLOR)

# Show image
plt.imshow(image, cmap='gray'), plt.axis('off')
plt.show()

# %% [markdown]
# ### Load Images As RGB

# %%
# Load image in color
image_bgr = cv2.imread('images/plane.jpg', cv2.IMREAD_COLOR)

# Convert to RGB
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(image_rgb), plt.axis('off')
plt.show()

# %% [markdown]
# ### View Image Data

# %%
# Show image data
image
# Out:
# array([[[ 48,  50,  51],
#         [ 51,  48,  50],
#         [ 57,  46,  49],
#         ...,
#         [ 71,  50,  29],
#         [ 71,  50,  29],
#         [ 72,  51,  30]],
#
#        [[ 99, 111, 115],
#         [109, 120, 124],
#         [ 87,  93,  98],
#         ...,
#         [ 74,  53,  32],
#         [ 74,  53,  32],
#         [ 74,  53,  32]],
#
#        [[175, 203, 210],
#         [175, 202, 212],
#         [173, 198, 208],
#         ...,
#         [ 74,  53,  32],
#         [ 74,  53,  32],
#         [ 74,  53,  32]],
#
#        ...,
#        [[ 33,  27,  22],
#         [ 33,  27,  20],
#         [ 34,  28,  21],
#         ...,
#         [ 78,  74,  73],
#         [ 78,  74,  73],
#         [ 78,  73,  74]],
#
#        [[ 33,  27,  22],
#         [ 33,  27,  22],
#         [ 33,  27,  20],
#         ...,
#         [ 75,  73,  72],
#         [ 74,  72,  72],
#         [ 72,  70,  70]],
#
#        [[ 33,  27,  22],
#         [ 33,  27,  22],
#         [ 33,  27,  20],
#         ...,
#         [ 75,  73,  72],
#         [ 73,  71,  71],
#         [ 70,  68,  68]]], dtype=uint8)

# %%
# Show dimensions
image.shape
# Out:
# (256, 256, 3)
