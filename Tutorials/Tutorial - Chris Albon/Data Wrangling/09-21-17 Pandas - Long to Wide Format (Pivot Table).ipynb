# %% [markdown]
# # Pandas: Long To Wide Format
# ### Import Modules

# %%
import pandas as pd

# %% [markdown]
# ### Create 'long' dataframe

# %%
raw_data = {'patient': [1, 1, 1, 2, 2], 
        'obs': [1, 2, 3, 1, 2], 
        'treatment': [0, 1, 0, 1, 0],
        'score': [6252, 24243, 2345, 2342, 23525]} 
df = pd.DataFrame(raw_data, columns = ['patient', 'obs', 'treatment', 'score'])
df
# Out:
#    patient  obs  treatment  score
# 0        1    1          0   6252
# 1        1    2          1  24243
# 2        1    3          0   2345
# 3        2    1          1   2342
# 4        2    2          0  23525

# %% [markdown]
# ### Make a "wide" data

# %%
df.pivot(index='patient', columns='obs', values='score')
# Out:
# obs           1        2       3
# patient
# 1        6252.0  24243.0  2345.0
# 2        2342.0  23525.0     NaN

# %% [markdown]
# Source: https://chrisalbon.com/python/pandas_long_to_wide.html
