# %% [markdown]
# # Rolling Time Windows
# ###  Preliminaries

# %%
# Load library
import pandas as pd

# %% [markdown]
# ###  Create Date Data

# %%
# Create datetimes
time_index = pd.date_range('01/01/2010', periods=5, freq='M')

# Create date frame, set index
df = pd.DataFrame(index=time_index)

# Create feature
df['Stock_Price'] = [1,2,3,4,5]

# %% [markdown]
# ###  Create A Rolling TIme Window of Two Rows

# %%
# Calculate rolling mean
df.rolling(window=2).mean()
# Out:
#             Stock_Price
# 2010-01-31          NaN
# 2010-02-28          1.5
# 2010-03-31          2.5
# 2010-04-30          3.5
# 2010-05-31          4.5

# %%
# Identify max value in rolling time window
df.rolling(window=2).max()
# Out:
#             Stock_Price
# 2010-01-31          NaN
# 2010-02-28          2.0
# 2010-03-31          3.0
# 2010-04-30          4.0
# 2010-05-31          5.0

# %% [markdown]
# Source: https://chrisalbon.com/machine-learning/rolling_time_windows.html
