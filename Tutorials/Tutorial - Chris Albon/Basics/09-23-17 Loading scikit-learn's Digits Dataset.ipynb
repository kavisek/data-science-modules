# %% [markdown]
# # Loading scikit-learn's Digits Dataset
# ### Preliminaries

# %%
# load libraries
from sklearn import datasets
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Digits Dataset

# %%
# Load Digits Datasets
digits = datasets.load_digits()

# Create feature matrix
X = digits.data

# Create targed vector
y = digits.target

# View the first observation's feature values
X[0]
# Out:
# array([  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.,   0.,   0.,  13.,
#         15.,  10.,  15.,   5.,   0.,   0.,   3.,  15.,   2.,   0.,  11.,
#          8.,   0.,   0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.,   0.,
#          5.,   8.,   0.,   0.,   9.,   8.,   0.,   0.,   4.,  11.,   0.,
#          1.,  12.,   7.,   0.,   0.,   2.,  14.,   5.,  10.,  12.,   0.,
#          0.,   0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.])

# %%
# View the first observation's feature values as a matrix
digits.images[0]
# Out:
# array([[  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.],
#        [  0.,   0.,  13.,  15.,  10.,  15.,   5.,   0.],
#        [  0.,   3.,  15.,   2.,   0.,  11.,   8.,   0.],
#        [  0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.],
#        [  0.,   5.,   8.,   0.,   0.,   9.,   8.,   0.],
#        [  0.,   4.,  11.,   0.,   1.,  12.,   7.,   0.],
#        [  0.,   2.,  14.,   5.,  10.,  12.,   0.,   0.],
#        [  0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.]])

# %%
# Visualize the first observatoins's featurs values as an image
plt.gray()
plt.matshow(digits.images[0])
plt.show()

# %% [markdown]
# Source: https://chrisalbon.com/machine-learning/loading_scikit-learns_digits-dataset.html
