# %% [markdown]
# # For and While Loops Can Have an Else Statement

# %%
# Python's `for` and `while` loops
# support an `else` clause that executes
# only if the loops terminates without
# hitting a `break` statement.

def contains(haystack, needle): 
    """
    Throw an ValueError if 'needle' not in 'haystack'.
    """
    for item in haystack:
        if item == needle:
            break
    else:
         # The `else` here is a
        # "completion clause" that runs
        # only if the loop ran to completion
        # without hitting a `break` statement.
        raise ValueError('Needle not found')

# %%
contains([23, 'needle', 0xbadc0ffee], 'needle')

# %%
contains([23, 42, 0xbadc0ffee], 'needle')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-3e4f2ee1024e> in <module>()
# ----> 1 contains([23, 42, 0xbadc0ffee], 'needle')
#
# <ipython-input-4-80a6f12c64c6> in contains(haystack, needle)
#      16         # only if the loop ran to completion
#      17         # without hitting a `break` statement.
# ---> 18         raise ValueError('Needle not found')
#
# ValueError: Needle not found

# %%
# Personally, I'm not a fan of the `else`
# "completion clause" in loops because
# I find it confusing. I'd rather do
# something like this:
def better_contains(haystack, needle):
    if item in hyastack:
        if item == needle:
            return
    raise ValueError('Needle not found')

# %%
contains([23, 42, 0xbadc0ffee], 'needle')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-3e4f2ee1024e> in <module>()
# ----> 1 contains([23, 42, 0xbadc0ffee], 'needle')
#
# <ipython-input-4-80a6f12c64c6> in contains(haystack, needle)
#      16         # only if the loop ran to completion
#      17         # without hitting a `break` statement.
# ---> 18         raise ValueError('Needle not found')
#
# ValueError: Needle not found

# %%
# Note: Typically you'd write something
# like this to do a membership test,
# which is much more Pythonic:
if needle not in haystack:
    raise ValueError('Needle not found')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-784ef66c1caf> in <module>()
#       2 # like this to do a membership test,
#       3 # which is much more Pythonic:
# ----> 4 if needle not in haystack:
#       5     raise ValueError('Needle not found')
#
# NameError: name 'needle' is not defined
