# %% [markdown]
# ### Test Multiple Flags

# %%
x, y, z  = 0,1,0
if x == 1 or y == 1 or z ==1:
    print('passed')
# Out:
# passed

# %%
if 1 in (x, y, z):
    print('passed')
# Out:
# passed

# %%
# This only test for truthfulness
if  any((x,y,z)):
    print('passed')
# Out:
# passed
