# %%
from skimage.io import imread
from skimage.transform import resize 
from matplotlib import pyplot as plt
import matplotlib.cm as cm

# %%
example_file = (
    "http://blog.johnmuellerbooks.com/" +
    "wp-content/uploads/2015/04/Layer-Hens.jpg")
image = imread(example_file, as_grey=True)
print image
# Out:
# [[ 0.28466706  0.27287961  0.2736902  ...,  0.31182667  0.3079051
#    0.28829725]
#  [ 0.27682392  0.27287961  0.27482902 ...,  0.32751294  0.32751294
#    0.31182667]
#  [ 0.26812471  0.27680118  0.28267216 ...,  0.33927765  0.33927765
#    0.33143451]
#  ...,
#  [ 0.54815451  0.55599765  0.55991922 ...,  0.30088745  0.30480902
#    0.31379098]
#  [ 0.54815451  0.55207608  0.55991922 ...,  0.21069137  0.2191      0.22808196]
#  [ 0.55207608  0.55599765  0.56384078 ...,  0.14066863  0.1423502
#    0.15133216]]

# %%
image2 = resize(image, (50, 50), mode='nearest')
print image2
# Out:
# [[ 0.51887942  0.48802372  0.4370432  ...,  0.33244235  0.3320851
#    0.24812157]
#  [ 0.50286078  0.43200684  0.51364794 ...,  0.35267294  0.28180235
#    0.32405882]
#  [ 0.50194157  0.54749473  0.60464784 ...,  0.32840525  0.26780314
#    0.30518745]
#  ...,
#  [ 0.58150431  0.31292549  0.43604995 ...,  0.02189686  0.02647412
#    0.16239916]
#  [ 0.57952706  0.31796618  0.41964706 ...,  0.02804235  0.03992718
#    0.15714144]
#  [ 0.5996549   0.30149316  0.54666902 ...,  0.20422588  0.09223507
#    0.31316667]]

# %%
# %matplotlib inline
plt.imshow(image, cmap=cm.gray)
plt.show()
