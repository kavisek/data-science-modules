# %% [markdown]
# ### Getting Started with Images
# Source: https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_gui/py_image_display/py_image_display.html#py-display-image

# %%
import cv2
import numpy

# %%
print (cv2.__version__)
# Out:
# 3.3.0

# %%
# Load an color image in grayscale
img = cv2.imread('Data/messi1.jpg', 0)

# %% [markdown]
# ### DIsplay the Image

# %%
# Show image in browser/local computer window

#cv2.imshow('image', img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %% [markdown]
# cv2.waitKey() is a keyboard binding function. Its argument is the time in milliseconds. The function waits for specified milliseconds for any keyboard event. If you press any key in that time, the program continues. If 0 is passed, it waits indefinitely for a key stroke. It can also be set to detect specific key strokes like, if key a is pressed etc which we will discuss below.
#
# cv2.destroyAllWindows() simply destroys all the windows we created. If you want to destroy any specific window, use the function cv2.destroyWindow() where you pass the exact window name as the argument.

# %%
# Show image in Jupyter & Matplot lib
import matplotlib.pyplot as plt  

plt.imshow(img)
plt.show()

# %%
# cv2.namedWindow('image', cv2.WINDOW_NORMAL)
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# cv2.namedWindow(). By default, the flag is cv2.WINDOW_AUTOSIZE. But if you specify flag to be cv2.WINDOW_NORMAL, you can resize window. It will be helpful when image is too large in dimension and adding track bar to windows.

# %% [markdown]
# ### Write an Image

# %%
cv2.imwrite('Data/messi2.png', img)
# Out:
# True

# %% [markdown]
# ### Using Matplotlib

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('Data/messi1.jpg', 0)
plt.imshow(img, cmap= 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) #hide tick values on axis
plt.show()
