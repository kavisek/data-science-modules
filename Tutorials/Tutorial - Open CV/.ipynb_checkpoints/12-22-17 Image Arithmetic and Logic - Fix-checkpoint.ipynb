# %% [markdown]
# ##### Image Operations
# Source: https://www.youtube.com/watch?v=1pzk_DIL_wo&index=4&list=PLQVvvaa0QuDdttJXlLtAJxJetJcqmqlQq

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 

img = cv2.imread('Data/messi1.jpg', cv2.IMREAD_COLOR)

px = img[55,55]
print(px)
# Out:
# [57 63 68]

# %%
roi = img[0:150, 0:150]
plt.imshow(roi); plt.show()

# %%
img = cv2.imread('Data/messi1.jpg', cv2.IMREAD_COLOR)

watch_face = img[37:111,107:194]
img[0:74,0:87] = watch_face
plt.imshow(img); plt.show()
