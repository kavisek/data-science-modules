# %% [markdown]
# ##### Image Arithimetic and Operations
# Source: https://www.youtube.com/watch?v=_gfNpJmWIug&list=PLQVvvaa0QuDdttJXlLtAJxJetJcqmqlQq&index=5

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 

img1 = cv2.imread('Data/messi1.jpg', cv2.IMREAD_COLOR)
img2 = cv2.imread('Data/messi2.jpg', cv2.IMREAD_COLOR) #black and white
add = img1 + img2


plt.imshow(add);plt.show()

# %%
img1 = cv2.imread('Data/messi1.jpg', cv2.IMREAD_COLOR)
img2 = cv2.imread('Data/messi2.jpg', cv2.IMREAD_COLOR) #black and white

# adding all the pixel values togther
add = cv2.add(img1, img2)


plt.imshow(add);plt.show()

# %%
img1 = cv2.imread('Data/messi1.jpg', cv2.IMREAD_COLOR)
img2 = cv2.imread('Data/messi2.jpg', cv2.IMREAD_COLOR) #black and white

# adding image pixels with weights
weighted = cv2.addWeighted(img1, 0.6, img2, 0.4, 0)


plt.imshow(add);plt.show()

# %%
img1 = cv2.imread('Data/messi1.jpg', cv2.IMREAD_COLOR)
img2 = cv2.imread('Data/j.png', cv2.IMREAD_COLOR) #black and white

rows, cols, channels = img2.shape
roi = img1[0:rows, 0:cols]

# create mask
img2gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 220, 255, cv2.THRESH_BINARY_INV)

plt.imshow(mask);plt.show()

# %%
img1 = cv2.imread('Data/messi1.jpg', cv2.IMREAD_COLOR)
img2 = cv2.imread('Data/j.png', cv2.IMREAD_COLOR) #black and white

rows, cols, channels = img2.shape
roi = img1[0:rows, 0:cols]

# create mask
img2gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 220, 255, cv2.THRESH_BINARY_INV)

mask_inv =  cv2.bitwise_not(mask)

img1_bg = cv2.bitwise_and(roi, roi, mask=mask_inv)
img2_fg = cv2.bitwise_and(img2, img2, mask=mask)

dst = cv2.add(img1_bg, img2_fg)
img1[0:rows, 0:cols] =dst

plt.imshow(mask);plt.show()
