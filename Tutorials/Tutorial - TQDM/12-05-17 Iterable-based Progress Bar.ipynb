# %% [markdown]
# ### Iterable-based Progress Bar
# Source: https://github.com/tqdm/tqdm

# %%
from tqdm import *
import time

# %%
pbar = tqdm(["a", "b", "c", "d"])
for char in pbar:
    time.sleep(.5)
    pbar.set_description("Processing %s" % char)
# Out:
# Processing d: 100%|██████████| 4/4 [00:02<00:00,  1.99it/s]
