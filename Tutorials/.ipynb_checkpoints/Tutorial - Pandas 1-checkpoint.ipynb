# %%
import pandas as pd
n = 1

#Specify Values for only Columns 

df = pd.DataFrame(
    {"a":[4,5,6],
     "b":[7,8,9]
     "c":[10,11,12]},
    index = [1,2,3])

#Specify values for Row and Columns

df = pd.Dataframe(
    [[4,7,8],
     [5,8,11]
     [6,9,12]],
    index=[1,2,3]
    columns = ['a','b','c'])

#Creating Datafram with a MultiIndex

df = pd.DataFrame(
    {"a":[4,5,6]
     "b":[7,8,9]
     "c":[10,11,12]}, 
    index = pd.MultiIndex.from_tuples(
        [('d',1),('d',2),('e',2)]
        names = ['n','v']))

#Reshapind Data

pd.melt(df) #Gather columns into rows
df.pivot(colums='var', values = 'val') #Spreat rows into columns
pd.concat([df1,df2]) #Append rows of a dataframe
pd.concat([df1,df2], axis = 1)

5 more add here

#Subset Rows/Observations

df[df.Length > 7] #Exact Row that meet logical criteria
df.drop_duplicates() #Remove duplicate rows (only considers columns)
df.head(n) #Selects first "n" wows
df.tail(n) #Selects last "n" rows
df.sample(frac=0.5) #Randomly selects fraction of rows
df.sample(n=10) #Randomly select n rows
df.iloc[10:20] #Select Rows by position
df.nlargest(n, 'value') #Select and order "n" entries
df.nsmallest(n, 'value') #Select and order bottom "n" entries

#Subset Columns/Variables

df[['width'],'lenght','species'] #Select multiple columns with specific names 
df['width'] #Select single columns with specfic name
df.width #Select single columns with specfic name
df.filter(regex='regex') #Selcet columns whose name matches regular experession
df.loc[:,'x2';'x4'] #Select columns between x2 and x4, inclusive 
df.iloc[;,[1,2,5]] #Select colmnse in position 1,2,5 ~ first column is 0
df.loc[df['a'] > 10, ['a','c']]

#Summarizing Data

df['Length'].value_counts() #Count number of rows with each unique value of variable
len(df) #number of row within dataframe
len(df['w'].unique()) #number of distinct values in a column
df.describe() #Basic descriptive statistics for each column )of Groupby
sum() #Sum values of an object
count() #count non-NA/null values of each object
min() #Minimum value of each object
max() #Maximum value of each object
mean() #Mean value of each object
var() #Variance of each object
std() #Standard Deviation of each object
median() #Median value of each object
quanitle([0.25,0.75]) #Quantiles of each object
apply(function) #Apply function to each object


#Group Data

df.groupby(by="col") #Return a groupby object, grouped by values in column named "col"
df.groupby(level ="ind") #Return a GroupBy object, grouped by values in index, level named "ind
agg(function) #Aggregate group using funciton
size() #Size of each group
agg() #aggregaet group using function
shift(1)#Copy with values shifted by 1
shift(-1) #Copy with value lagged by -1
rank(method='dense') #Ranks with no gaps
rank(method='min') #Ranks. Ties get min rank
rank(pct=True) #Rank rescaled to internval[0,1]
rank(method='first') #Ranks. Ties go to first value
cumsum()
cummax()
cummin()
cumprod()

#Plotting
df.plot.hist() #A Histogram of each column
df.plot .scatter(x='w',y='h')


#Combine Data Set (Rows)

pd.merge(adf,bdf, how='left', on='x1') #Join matching rows from bdf and adf
pd.merge(adf,bdf,how='righ', on='x1') #Join mathing rows from adfa and bdf
pd.merge(adf,bdf,how='inner', on='x1') #Join data. Retain only rows in both sets
pd.merge(adf, bdf, how ='outer', on='x1') #Join data. Retain all values, and all rows

adf[adf.x1.isin(bdf.x1)]
adf[~adf.x1,isin(bdf.x1)]

#Combine Data Set (Columns)

pd.merge(ydf, zdf) #Rows that appear in both ydf and zdf
pd.merge(ydf, zdf, how='outer') #Rows that appea in either or both ydf and zdf
pd.merge(ydf zdf, how='outer', indicator = TRUE).query('_merge == "left only"').drop(['_merge'], axis = 1) #Rows that appeat in ydf but not zdf
# Out:
#   File "<ipython-input-35-0731e2ec9983>", line 9
#     columns = ['a','b','c'])
#           ^
# SyntaxError: invalid syntax
