# %% [markdown]
# # House Price: Advance Regression Techniques

# %% [markdown]
# Link: https://www.kaggle.com/apapiu/regularized-linear-models

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from scipy.stats import skew
from scipy.stats.stats import pearsonr 


sample_submission = pd.DataFrame(pd.read_csv('sample_submission.csv'))
test_df =  pd.DataFrame(pd.read_csv('test.csv'))
train_df =  pd.DataFrame(pd.read_csv('train.csv'))

combine = [train_df, test_df]

# %%
sample_submission.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
train_df.shape, test_df.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
pd.set_option('display.max_columns', 85)
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
null_values = pd.DataFrame(train_df.isnull().sum()[train_df.isnull().sum() > 0])
null_values
# Out:
#                  0
# LotFrontage    259
# Alley         1369
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC        1453
# Fence         1179
# MiscFeature   1406

# %%
train_df[list(null_values.index)].sample(n=7)
# Out:
#       LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 1187         89.0   NaN       None         0.0       Gd       TA           No
# 755          34.0  Pave    BrkFace       894.0       Gd       TA           No
# 25          110.0   NaN      Stone       640.0       Gd       TA           No
# 101          77.0   NaN    BrkFace       336.0       Gd       TA           No
# 1172         35.0  Pave       None         0.0       Gd       TA           No
# 1146          NaN   NaN    BrkFace        85.0       Gd       TA           No
# 785           NaN   NaN       None         0.0       TA       TA           No
#
#      BsmtFinType1 BsmtFinType2 Electrical FireplaceQu GarageType  GarageYrBlt  \
# 1187          GLQ          Unf      SBrkr          Fa     Attchd       1994.0
# 755           GLQ          Unf      SBrkr         NaN     Detchd       1999.0
# 25            Unf          Unf      SBrkr          Gd     Attchd       2007.0
# ...

# %%
null_values.row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-12f3501ca57d> in <module>()
# ----> 1 null_values.row
#
# /Users/kavisekhon/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
for dataset in combine: 
    dataset.LotFrontage.fillna(dataset.LotFrontage.mean())
    dataset.MasVnrArea.fillna()
    dataset.GarageYrBlt.fillna()
