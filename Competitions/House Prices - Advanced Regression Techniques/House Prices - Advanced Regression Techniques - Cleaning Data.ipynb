# %% [markdown]
# # House Price: Advance Regression Techniques

# %% [markdown]
# Link: https://www.kaggle.com/apapiu/regularized-linear-models

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from scipy.stats import skew
from scipy.stats.stats import pearsonr

# Set Pandas Options
pd.set_option('max_columns',100)

# %% [markdown]
# ### Import Data

# %%
sample_submission = pd.DataFrame(pd.read_csv('Data/sample_submission.csv',
                                            index_col = 'Id'))
test_df =  pd.DataFrame(pd.read_csv('Data/test.csv'))
train_df =  pd.DataFrame(pd.read_csv('Data/train.csv'))

datsets = [train_df, test_df]

# %%
# What the submission file will have to look like
sample_submission.head()
# Out:
#           SalePrice
# Id
# 1461  169277.052498
# 1462  187758.393989
# 1463  183583.683570
# 1464  179317.477511
# 1465  150730.079977

# %%
# Training set size and length, respectively. 
print('Training Set:',train_df.shape)
print('Test Set:',test_df.shape)
# Out:
# Training Set: (1460, 81)
# Test Set: (1459, 80)

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ### Fining and Observing For Null Values

# %%
null = pd.DataFrame(train_df.isnull().sum(), columns=['Null'])
null = null[null['Null'] > 0]
null_cols = null.index
null
# Out:
#               Null
# LotFrontage    259
# Alley         1369
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC        1453
# Fence         1179
# MiscFeature   1406

# %%
null_num

for i in null_cols:
    print(i, ':' ,train_df[i].dtype)
# Out:
# LotFrontage : float64
# Alley : object
# MasVnrType : object
# MasVnrArea : float64
# BsmtQual : object
# BsmtCond : object
# BsmtExposure : object
# BsmtFinType1 : object
# BsmtFinType2 : object
# Electrical : object
# FireplaceQu : object
# GarageType : object
# GarageYrBlt : float64
# GarageFinish : object
# GarageQual : object
# GarageCond : object
# PoolQC : object
# Fence : object
# MiscFeature : object

# %% [markdown]
# ### Assesing in Null Values

# %%
for i in null_cols:
    print(i)
    train_df[i].plot()
# Out:
# LotFrontage
# Alley
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-47a0f12510f0> in <module>()
#       1 for i in null_cols:
#       2     print(i)
# ----> 3     train_df[i].plot()
#
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2451                            colormap=colormap, table=table, yerr=yerr,
#    2452                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2453                            **kwds)
#    2454     __call__.__doc__ = plot_series.__doc__
#    2455
#
# ...

# %%
train_df['MasVnrType']
# Out:
# 0       BrkFace
# 1          None
# 2       BrkFace
# 3          None
# 4       BrkFace
# 5          None
# 6         Stone
# 7         Stone
# 8          None
# 9          None
# 10         None
# 11        Stone
# 12         None
# 13        Stone
# 14      BrkFace
# 15         None
# 16      BrkFace
# 17         None
# 18         None
# 19         None
# 20      BrkFace
# 21         None
# 22      BrkFace
# 23         None
# 24         None
# 25        Stone
# 26         None
# 27        Stone
# 28         None
# 29         None
#          ...
# 1430       None
# 1431       None
# 1432       None
# 1433    BrkFace
# 1434       None
# 1435    BrkFace
# 1436       None
# 1437      Stone
# 1438       None
# 1439    BrkFace
# 1440       None
# 1441    BrkFace
# 1442      Stone
# 1443       None
# 1444    BrkFace
# 1445       None
# 1446    BrkFace
# 1447    BrkFace
# 1448       None
# 1449       None
# 1450       None
# 1451      Stone
# 1452    BrkFace
# 1453       None
# ...
