# %% [markdown]
# # <center> Feature Engineering I

# %%
import pandas as pd 
import numpy as np

hpg = pd.read_csv('https://www.dropbox.com/s/86sl12ma06pmhi8/reserve.csv?dl=1')
air = pd.read_csv('https://www.dropbox.com/s/t1r5fn5rolbvpqd/visits_reserve.csv?dl=1')
#air_hpg = read.csv('https://www.dropbox.com/s/86sl12ma06pmhi8/reserve.csv?dl=1')

# %%
hpg.head()
# Out:
#    Unnamed: 0          air_store_id          hpg_store_id hpg_genre_name  \
# 0           0  air_a24bf50c3e90d583  hpg_c34b496d0305a809        Italian
# 1           1  air_a24bf50c3e90d583  hpg_c34b496d0305a809        Italian
# 2           2  air_a24bf50c3e90d583  hpg_c34b496d0305a809        Italian
# 3           3  air_a24bf50c3e90d583  hpg_c34b496d0305a809        Italian
# 4           4  air_a24bf50c3e90d583  hpg_c34b496d0305a809        Italian
#
#                             hpg_area_name   latitude   longitude  \
# 0  Shizuoka-ken Hamamatsu-shi Sukenobuchō  34.721644  137.738944
# 1  Shizuoka-ken Hamamatsu-shi Sukenobuchō  34.721644  137.738944
# 2  Shizuoka-ken Hamamatsu-shi Sukenobuchō  34.721644  137.738944
# 3  Shizuoka-ken Hamamatsu-shi Sukenobuchō  34.721644  137.738944
# 4  Shizuoka-ken Hamamatsu-shi Sukenobuchō  34.721644  137.738944
#
#         visit_datetime     reserve_datetime  reserve_visitors
# 0  2016-01-06 19:00:00  2016-01-06 13:00:00                 2
# 1  2016-01-07 21:00:00  2016-01-03 19:00:00                 6
# 2  2016-01-08 19:00:00  2016-01-07 14:00:00                 2
# 3  2016-01-09 19:00:00  2016-01-02 21:00:00                 2
# 4  2016-01-09 19:00:00  2016-01-07 09:00:00                 2

# %%
air.head()
# Out:
#    Unnamed: 0          air_store_id          hpg_store_id air_genre_name  \
# 0           0  air_63b13c56b7201bd9  hpg_4bc649e72e2a239a    Cafe/Sweets
# 1           1  air_63b13c56b7201bd9  hpg_4bc649e72e2a239a    Cafe/Sweets
# 2           2  air_63b13c56b7201bd9  hpg_4bc649e72e2a239a    Cafe/Sweets
# 3           3  air_63b13c56b7201bd9  hpg_4bc649e72e2a239a    Cafe/Sweets
# 4           4  air_63b13c56b7201bd9  hpg_4bc649e72e2a239a    Cafe/Sweets
#
#                     air_area_name   latitude   longitude  visit_date  \
# 0  Fukuoka-ken Fukuoka-shi Daimyō  33.586994  130.394894  2016-01-02
# 1  Fukuoka-ken Fukuoka-shi Daimyō  33.586994  130.394894  2016-01-02
# 2  Fukuoka-ken Fukuoka-shi Daimyō  33.586994  130.394894  2016-01-02
# 3  Fukuoka-ken Fukuoka-shi Daimyō  33.586994  130.394894  2016-01-02
# 4  Fukuoka-ken Fukuoka-shi Daimyō  33.586994  130.394894  2016-01-02
#
#    visitors       visit_datetime     reserve_datetime  reserve_visitors  \
# 0        12  2017-02-10 13:00:00  2017-02-09 14:00:00                 5
# 1        12  2017-02-10 13:00:00  2017-02-09 14:00:00                 5
# 2        12  2017-02-11 12:00:00  2017-02-09 15:00:00                 3
# 3        12  2017-02-11 12:00:00  2017-02-09 15:00:00                 2
# 4        12  2017-02-11 12:00:00  2017-02-09 15:00:00                 6
#
#   calendar_date day_of_week  holiday_flg
# 0    2016-01-02    Saturday            1
# 1    2016-01-02    Saturday            1
# 2    2016-01-02    Saturday            1
# 3    2016-01-02    Saturday            1
# 4    2016-01-02    Saturday            1

# %%
air_hpg.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3f7d95664d62> in <module>()
# ----> 1 air_hpg.head()
#
# NameError: name 'air_hpg' is not defined

# %% [markdown]
# ### Viewing Features
