# %% [markdown]
# # <center> Cleaning Data I

# %% [markdown]
# ### Import Modules

# %%
# Import Modules
import pandas as pd

# Import Data
sample = pd.read_csv('https://www.dropbox.com/s/15jplg1yt05zl28/sample_submission.csv?dl=1', index_col='Id')
test_df = pd.read_csv('https://www.dropbox.com/s/v2m4seozmqxyh3x/test.csv?dl=1', index_col='Id')
train_df = pd.read_csv('https://www.dropbox.com/s/n95phfnwft9no0h/train.csv?dl=1', index_col='Id')


dfs = [train_df, test_df]
# View Sample Submission
sample.head(5)
# Out:
#           SalePrice
# Id
# 1461  169277.052498
# 1462  187758.393989
# 1463  183583.683570
# 1464  179317.477511
# 1465  150730.079977

# %%
# Training and Testing Data Shape
print('Training Shape:', train_df.shape)
print('Test Shape:', test_df.shape)
# Out:
# Training Shape: (1460, 80)
# Test Shape: (1459, 79)

# %%
# View training data
train_df.sample(5)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1070          45       RL         60.0     9600   Pave   NaN      Reg
# 575           80       RL         70.0    10500   Pave   NaN      Reg
# 1306          20       RL        108.0    13173   Pave   NaN      IR1
# 600          160       RM         24.0     1950   Pave   NaN      Reg
# 62            75       RM         60.0     7200   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# Id                                      ...
# 1070         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 575          Lvl    AllPub       FR2    ...            0    NaN   GdWo
# 1306         Lvl    AllPub    Corner    ...            0    NaN    NaN
# 600          Lvl    AllPub    Inside    ...            0    NaN  GdPrv
# 62           Lvl    AllPub    Inside    ...            0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1070         NaN       0      5    2007        WD         Normal     135000
# 575          NaN       0     12    2007        WD         Normal     139000
# 1306         NaN       0     11    2009        WD         Normal     325000
# 600          NaN       0      7    2008       COD         Normal     151000
# 62           NaN       0      3    2007        WD         Normal     101000
#
# [5 rows x 80 columns]

# %%
# View Training Data
test_df.sample(5)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2094          30       RM         60.0     5400   Pave   NaN      Reg
# 1804          90       RL         75.0     8604   Pave   NaN      IR1
# 2775          50       RM         60.0     5520   Pave   NaN      Reg
# 2720          20       RL         78.0    10140   Pave   NaN      Reg
# 2251          70      NaN          NaN    56600   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 2094         Lvl    AllPub    Inside      ...                 0        0
# 1804         Lvl    AllPub    Inside      ...                 0        0
# 2775         Lvl    AllPub    Corner      ...                 0        0
# 2720         Lvl    AllPub    Inside      ...               264        0
# 2251         Low    AllPub    Inside      ...                 0        0
#
#      PoolQC Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 2094    NaN   NaN         NaN       0       2    2008        WD         Normal
# 1804    NaN   NaN         NaN       0      11    2009        WD         Normal
# 2775    NaN   NaN         NaN       0       7    2006        WD         Normal
# 2720    NaN   NaN         NaN       0       4    2006        WD         Normal
# 2251    NaN   NaN         NaN       0       1    2008        WD         Normal
#
# [5 rows x 79 columns]

# %% [markdown]
# ### Checking Null Values

# %%
train_df.LotFrontage.dtype
# Out:
# dtype('float64')

# %%
# Training Data Null Values
train_null = pd.DataFrame(train_df.isnull().sum(), columns=['Train_df'])
train_null = train_null[train_null['Train_df'] > 0]

# Training Data Null Values
test_null = pd.DataFrame(test_df.isnull().sum(), columns=['Test_df'])
test_null = test_null[test_null['Test_df'] > 0]

pd.concat([train_null, test_null], axis=1).fillna(0)
# Out:
#               Train_df  Test_df
# Alley           1369.0   1352.0
# BsmtCond          37.0     45.0
# BsmtExposure      38.0     44.0
# BsmtFinSF1         0.0      1.0
# BsmtFinSF2         0.0      1.0
# BsmtFinType1      37.0     42.0
# BsmtFinType2      38.0     42.0
# BsmtFullBath       0.0      2.0
# BsmtHalfBath       0.0      2.0
# BsmtQual          37.0     44.0
# BsmtUnfSF          0.0      1.0
# Electrical         1.0      0.0
# Exterior1st        0.0      1.0
# Exterior2nd        0.0      1.0
# Fence           1179.0   1169.0
# FireplaceQu      690.0    730.0
# Functional         0.0      2.0
# GarageArea         0.0      1.0
# GarageCars         0.0      1.0
# GarageCond        81.0     78.0
# GarageFinish      81.0     78.0
# GarageQual        81.0     78.0
# GarageType        81.0     76.0
# GarageYrBlt       81.0     78.0
# KitchenQual        0.0      1.0
# LotFrontage      259.0    227.0
# MSZoning           0.0      4.0
# MasVnrArea         8.0     15.0
# MasVnrType         8.0     16.0
# MiscFeature     1406.0   1408.0
# PoolQC          1453.0   1456.0
# SaleType           0.0      1.0
# TotalBsmtSF        0.0      1.0
# Utilities          0.0      2.0

# %% [markdown]
# ### Replace Null Values with their Mean

# %%
object_columns = list(train_df.select_dtypes('object').columns.values)
numeric_columns = list(train_df.select_dtypes(['float64','int64']).columns.values)

# %%
train_df[train_df[object_columns]].fillna(value='Unknown', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-beb4e18fd447> in <module>()
# ----> 1 train_df[train_df[object_columns]].fillna(value='Unknown', inplace=True)
#
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
# -> 2135             return self._getitem_frame(key)
#    2136         elif is_mi_columns:
#    2137             return self._getitem_multilevel(key)
#
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_frame(self, key)
#    2216     def _getitem_frame(self, key):
#    2217         if key.values.size and not is_bool_dtype(key.values):
# -> 2218             raise ValueError('Must pass DataFrame with boolean values only')
#    2219         return self.where(key)
#    2220
#
# ValueError: Must pass DataFrame with boolean values only

# %%
train_df[train_df['MSZoning',
 'Street',
 'Alley',
 'LotShape',
 'LandContour',
 'Utilities',
 'LotConfig',
 'LandSlope',
 'Neighborhood',
 'Condition1',
 'Condition2',
 'BldgType',
 'HouseStyle',
 'RoofStyle',
 'RoofMatl',
 'Exterior1st',
 'Exterior2nd',
 'MasVnrType',
 'ExterQual',
 'ExterCond',
 'Foundation',
 'BsmtQual',
 'BsmtCond',
 'BsmtExposure',
 'BsmtFinType1',
 'BsmtFinType2',
 'Heating',
 'HeatingQC',
 'CentralAir',
 'Electrical',
 'KitchenQual',
 'Functional',
 'FireplaceQu',
 'GarageType',
 'GarageFinish',
 'GarageQual',
 'GarageCond',
 'PavedDrive',
 'PoolQC',
 'Fence',
 'MiscFeature',
 'SaleType',
 'SaleCondition']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-3dc0cc342866> in <module>()
#      41  'MiscFeature',
#      42  'SaleType',
# ---> 43  'SaleCondition']]
#
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/Kavi/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition')

# %%
list(object_columns)
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
object_columns
# Out:
# array(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'], dtype=object)

# %%
object_columns.values
# Out:
# array(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'], dtype=object)
