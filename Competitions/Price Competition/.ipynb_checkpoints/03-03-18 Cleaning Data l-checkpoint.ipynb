# %% [markdown]
# # <center> Cleaning Data I

# %% [markdown]
# ### Import Modules

# %%
# Import Modules
import pandas as pd

# Import Data
sample = pd.read_csv('https://www.dropbox.com/s/15jplg1yt05zl28/sample_submission.csv?dl=1', index_col='Id')
test_df = pd.read_csv('https://www.dropbox.com/s/v2m4seozmqxyh3x/test.csv?dl=1', index_col='Id')
train_df = pd.read_csv('https://www.dropbox.com/s/n95phfnwft9no0h/train.csv?dl=1', index_col='Id')


dfs = [train_df, test_df]
# View Sample Submission
sample.head(5)
# Out:
#           SalePrice
# Id
# 1461  169277.052498
# 1462  187758.393989
# 1463  183583.683570
# 1464  179317.477511
# 1465  150730.079977

# %%
# Training and Testing Data Shape
print('Training Shape:', train_df.shape)
print('Test Shape:', test_df.shape)
# Out:
# Training Shape: (1460, 80)
# Test Shape: (1459, 79)

# %%
# View training data
train_df.sample(5)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 652           70       RL         60.0     9084   Pave   NaN      Reg
# 1432         120       RL          NaN     4928   Pave   NaN      IR1
# 363           85       RL         64.0     7301   Pave   NaN      Reg
# 137           20       RL          NaN    10355   Pave   NaN      IR1
# 956           90       RH         82.0     7136   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# Id                                      ...
# 652          Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 1432         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 363          Lvl    AllPub    Corner    ...            0    NaN    NaN
# 137          Lvl    AllPub    Corner    ...            0    NaN    NaN
# 956          HLS    AllPub    Inside    ...            0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 652          NaN       0     10    2009        WD         Normal     108000
# 1432         NaN       0     10    2009        WD         Normal     143750
# 363          NaN       0      7    2009     ConLD         Normal     198500
# 137          NaN       0      7    2007        WD         Normal     143000
# 956          NaN       0      8    2007        WD         Normal     145000
#
# [5 rows x 80 columns]

# %%
# View Training Data
test_df.sample(5)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2444          50       RM        120.0     9000   Pave   NaN      Reg
# 2392          20       RL         70.0     8680   Pave   NaN      Reg
# 2781          30       RM         50.0     5633   Pave  Pave      Reg
# 1722          20       RL         63.0    13072   Pave   NaN      Reg
# 2351          20       FV         84.0    10440   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 2444         Lvl    AllPub    Corner      ...                 0        0
# 2392         Lvl    AllPub    Inside      ...                 0        0
# 2781         Lvl    AllPub    Inside      ...                 0        0
# 1722         Lvl    AllPub    Inside      ...                 0        0
# 2351         Lvl    AllPub    Corner      ...                 0        0
#
#      PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# Id
# 2444    NaN  MnPrv         NaN       0       6    2007        WD
# 2392    NaN    NaN         NaN       0       1    2007        WD
# 2781    NaN    NaN         NaN       0       7    2006        WD
# 1722    NaN    NaN         NaN       0       8    2009        WD
# 2351    NaN    NaN         NaN       0       5    2007       New
#
#       SaleCondition
# Id
# 2444         Normal
# 2392         Normal
# 2781         Normal
# 1722         Normal
# 2351        Partial
#
# [5 rows x 79 columns]

# %% [markdown]
# ### Checking Null Values

# %%
train_df.LotFrontage.dtype
# Out:
# dtype('float64')

# %%
# Training Data Null Values
train_null = pd.DataFrame(train_df.isnull().sum(), columns=['Train_df'])
train_null = train_null[train_null['Train_df'] > 0]

# Training Data Null Values
test_null = pd.DataFrame(test_df.isnull().sum(), columns=['Test_df'])
test_null = test_null[test_null['Test_df'] > 0]

pd.concat([train_null, test_null], axis=1).fillna(0)
# Out:
#               Train_df  Test_df
# Alley           1369.0   1352.0
# BsmtCond          37.0     45.0
# BsmtExposure      38.0     44.0
# BsmtFinSF1         0.0      1.0
# BsmtFinSF2         0.0      1.0
# BsmtFinType1      37.0     42.0
# BsmtFinType2      38.0     42.0
# BsmtFullBath       0.0      2.0
# BsmtHalfBath       0.0      2.0
# BsmtQual          37.0     44.0
# BsmtUnfSF          0.0      1.0
# Electrical         1.0      0.0
# Exterior1st        0.0      1.0
# Exterior2nd        0.0      1.0
# Fence           1179.0   1169.0
# FireplaceQu      690.0    730.0
# Functional         0.0      2.0
# GarageArea         0.0      1.0
# GarageCars         0.0      1.0
# GarageCond        81.0     78.0
# GarageFinish      81.0     78.0
# GarageQual        81.0     78.0
# GarageType        81.0     76.0
# GarageYrBlt       81.0     78.0
# KitchenQual        0.0      1.0
# LotFrontage      259.0    227.0
# MSZoning           0.0      4.0
# MasVnrArea         8.0     15.0
# MasVnrType         8.0     16.0
# MiscFeature     1406.0   1408.0
# PoolQC          1453.0   1456.0
# SaleType           0.0      1.0
# TotalBsmtSF        0.0      1.0
# Utilities          0.0      2.0

# %% [markdown]
# ### Replace Null Values with their Mean

# %%
object_columns = test_df.select_dtypes('object').columns.values
numeric_columns = test_df.select_dtypes(['float64','int64']).columns.values

# %%
for feature in object_columns:
  train_df[feature]  = train_df[feature].fillna(value='Unknown')
  test_df[feature]  = test_df[feature].fillna(value='Unknown')
  
for feature in numeric_columns:
  train_df[feature]  = train_df[feature].fillna(value = test_df[feature].mean())
  test_df[feature]  = test_df[feature].fillna(value = test_df[feature].mean())

# %% [markdown]
# ### Export Cleaned Data

# %%
train_df.to_csv('Data/cleaned_train_df.csv', index=True)
test_df.to_csv('Data/cleaned_test_df.csv', index=True)
