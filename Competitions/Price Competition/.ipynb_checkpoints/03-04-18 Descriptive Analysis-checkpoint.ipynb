# %% [markdown]
# # <center> Descriptive Analysis

# %% [markdown]
# ### Import Prelminaries

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

train_df = pd.read_csv('https://www.dropbox.com/s/nqftja8aa01z4mn/cleaned_train_df.csv?dl=1', index_col='Id')
test_df = pd.read_csv('https://www.dropbox.com/s/gw7fi8o71kczq6q/cleaned_test_df.csv?dl=1', index_col='Id')

print('Training Dataframe:', train_df.shape)
print('Test Dataframe:', test_df.shape)
# Out:
# Training Dataframe: (1460, 80)
# Test Dataframe: (1459, 79)

# %%
# View the dataframe
train_df.head(5)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  Unknown      Reg
# 2           20       RL         80.0     9600   Pave  Unknown      Reg
# 3           60       RL         68.0    11250   Pave  Unknown      IR1
# 4           70       RL         60.0     9550   Pave  Unknown      IR1
# 5           60       RL         84.0    14260   Pave  Unknown      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea   PoolQC    Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0  Unknown  Unknown
# 2          Lvl    AllPub       FR2    ...            0  Unknown  Unknown
# 3          Lvl    AllPub    Inside    ...            0  Unknown  Unknown
# 4          Lvl    AllPub    Corner    ...            0  Unknown  Unknown
# 5          Lvl    AllPub       FR2    ...            0  Unknown  Unknown
#
# ...

# %% [markdown]
# ### Quantative Values Histogram Values

# %%
for col in train_df.select_dtypes(['int64','float64']):
  plt.figure()
  train_df[col].hist(color='black',grid=False, edgecolor='w' )
  plt.title(str(train_df[col].name + ' Histogram'))
  plt.xlabel(str(train_df[col].name ))
  plt.ylabel('Frequency')
  
  plt.axvline(train_df[col].mean(), color='r', 
              linestyle='dashed', linewidth=2)
# Out:
# /Users/Kavi/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ### Quantative Correlation Matrix

# %%
def df_palette(val):
  color = 'darkred' if val < 0 else 'green'
  if val == 0 or val == 1: color = 'black' 
  return 'color: %s'%color

# %%
corr_matrix = train_df.select_dtypes(['int64','float64']).corr()
corr_matrix.style.applymap(df_palette)
# Out:
# <style  type="text/css" >
#     #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col0 {
#             color:  black;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col1 {
#             color:  darkred;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col2 {
#             color:  darkred;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col3 {
#             color:  green;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col4 {
#             color:  darkred;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col5 {
#             color:  green;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col6 {
#             color:  green;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col7 {
#             color:  green;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col8 {
#             color:  darkred;
#         }    #T_dc71064c_2037_11e8_a936_7831c1d3f646row0_col9 {
#             color:  darkred;
# ...

# %% [markdown]
# ### Qualitative Histogram Counts

# %%
for col in train_df.select_dtypes('object'):
  df = pd.DataFrame(train_df[col].value_counts()).plot.barh(
  color='darkred',edgecolor='w')
  df.columns = ['Count']
  plt.title(str(train_df[col].name) + "Count")
  plt.xlabel(str(train_df[col].name))
  plt.ylabel('Frequency')
# Out:
# /Users/Kavi/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# Author: Kavi
