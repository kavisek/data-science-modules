# %% [markdown]
# # <center> PCA Analysis

# %%
# Import modules
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder

# %%
# Import data
train_df = pd.DataFrame(pd.read_csv('https://www.dropbox.com/s/m2xk1588efn3icv/cleaned_train_df.csv?dl=1'))
test_df = pd.DataFrame(pd.read_csv('https://www.dropbox.com/s/zlq1xsznwg2a7z6/cleaned_test_df.csv?dl=1'))

# Label Encoding Feature Data
EncodeDataFrame(train_df)

# Convert dataframe to values
X = train_df[1:].values
y = train_df['Survived'].values 

# Factor analysis
pca = PCA().fit(X)
print ('Explained variance by component: %s' %pca.explained_variance_ratio_)
pd.DataFrame(pca.components_, columns = train_df.columns)
# Out:
# Explained variance by component: [  3.94090673e-01   3.58152074e-01   2.26004230e-01   1.65909238e-02
#    4.25218202e-03   8.92936275e-04   7.12590788e-06   3.30406220e-06
#    2.72411386e-06   1.94524656e-06   1.34380578e-06   5.38244519e-07]
#     PassengerId  Survived    Pclass      Name       Sex       Age     SibSp  \
# 0      0.703489  0.000099 -0.000302 -0.698143  0.000016 -0.000465 -0.000150
# 1     -0.703880  0.000093 -0.000053 -0.710255 -0.000093 -0.003105  0.000234
# 2     -0.098202  0.000379 -0.001293  0.089227 -0.000138  0.004386 -0.000400
# 3     -0.002893  0.002398 -0.009686  0.012517 -0.001483  0.035220  0.002536
# 4      0.001717 -0.000483  0.007938 -0.001897 -0.001155 -0.105252  0.006892
# 5     -0.001157 -0.005152 -0.011068 -0.003586  0.004026  0.993452 -0.018914
# 6      0.000177 -0.037865  0.064747  0.000054 -0.049076  0.022878  0.893957
# 7      0.000098  0.119967  0.005140 -0.000054 -0.125088  0.005249  0.140188
# 8     -0.000057  0.182643  0.006421  0.000090 -0.257959  0.004101 -0.407629
# 9     -0.000080 -0.545584  0.655760 -0.000049  0.450632  0.003617 -0.115500
# 10    -0.000051 -0.362897 -0.741733  0.000016  0.503776 -0.010548 -0.021573
# 11    -0.000030  0.722098  0.123573  0.000032  0.677142  0.003622  0.028443
#
#        Parch    Ticket      Fare     Cabin  Embarked
# 0   0.000093 -0.132113  0.008771 -0.012954  0.000040
# 1   0.000122  0.005941  0.005959 -0.003366 -0.000020
# 2  -0.000097 -0.990292  0.001694 -0.041148 -0.000015
# 3   0.002759  0.022009  0.889372 -0.454970 -0.003646
# 4   0.004390 -0.036711  0.456651  0.882555  0.001570
# 5  -0.011393 -0.000328  0.016971  0.109982  0.001305
# 6   0.413977 -0.000237 -0.005632 -0.004332  0.144413
# 7   0.032169 -0.000105 -0.003704  0.002872 -0.974268
# 8   0.856291  0.000195 -0.002278  0.000260  0.025295
# 9   0.196113 -0.000762  0.004618 -0.007435 -0.131743
# 10  0.227716  0.000415 -0.003419  0.006890 -0.108889
# 11  0.062306  0.000026  0.000137 -0.000016  0.008797
