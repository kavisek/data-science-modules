# %% [markdown]
# # <center>  Sequential Neural Net
# * Sequential CNN, 10 epochs
# * Note use predict_classes and not predict when generating model predictions with keras
# ### Import Preliminaries

# %%
% matplotlib inline

# Import modules
import pandas as pd
import keras

# Import dataframe
train_df = pd.DataFrame(pd.read_csv('https://www.dropbox.com/s/3zeaj89zl0e607x/featured_train_df2.csv?dl=1',index_col='PassengerId'))
test_df = pd.DataFrame(pd.read_csv('https://www.dropbox.com/s/gr0rboxonowwh91/featured_test_df2.csv?dl=1', index_col='PassengerId'))


# Set pandas options
pd.set_option('precision',8)
pd.set_option('max_columns',100)
pd.set_option('max_rows',100)

dfs = [train_df, test_df]

# %% [markdown]
# ### Dataframe to values

# %%
# Convert pandas dataframe into prediction values and data
y = train_df.Survived.values
X = train_df[train_df.columns[1:]].values

X_test = test_df.values

# %% [markdown]
# ### Binary Classification Model

# %%
num_features = train_df[train_df.columns[1:]].shape[1]

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(32, activation='relu', input_dim=num_features))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy',
             metrics=['accuracy'])

# Train the model, iterating on the data in batches of 32 samples
model.fit(X, y, epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 889/889 [==============================] - 0s 499us/step - loss: 4.4393 - acc: 0.5849
# Epoch 2/15
# 889/889 [==============================] - 0s 69us/step - loss: 2.9134 - acc: 0.6535
# Epoch 3/15
# 889/889 [==============================] - 0s 69us/step - loss: 2.0000 - acc: 0.6209
# Epoch 4/15
# 889/889 [==============================] - 0s 75us/step - loss: 1.8168 - acc: 0.6243
# Epoch 5/15
# 889/889 [==============================] - 0s 66us/step - loss: 1.6807 - acc: 0.6130
# Epoch 6/15
# 889/889 [==============================] - 0s 81us/step - loss: 1.5673 - acc: 0.6108
# Epoch 7/15
# 889/889 [==============================] - 0s 75us/step - loss: 1.3446 - acc: 0.6299
# Epoch 8/15
# 889/889 [==============================] - 0s 73us/step - loss: 1.4586 - acc: 0.6187
# Epoch 9/15
# 889/889 [==============================] - 0s 79us/step - loss: 1.2955 - acc: 0.6502
# Epoch 10/15
# 889/889 [==============================] - 0s 71us/step - loss: 1.2746 - acc: 0.6322
# Epoch 11/15
# 889/889 [==============================] - 0s 69us/step - loss: 1.3048 - acc: 0.6423
# Epoch 12/15
# 889/889 [==============================] - 0s 76us/step - loss: 1.2816 - acc: 0.6310
# Epoch 13/15
# 889/889 [==============================] - 0s 74us/step - loss: 1.2080 - acc: 0.6187
# Epoch 14/15
# 889/889 [==============================] - 0s 82us/step - loss: 1.3177 - acc: 0.6018
# Epoch 15/15
# 889/889 [==============================] - 0s 74us/step - loss: 1.0791 - acc: 0.6502

# %% [markdown]
# ### Predict Results

# %%
prediction = pd.DataFrame(model.predict_classes(X_test), columns=['Survived'])
prediction.head()
prediction = pd.concat([prediction,
                        pd.Series(test_df.index, name='PassengerId') ], axis=1)
# Out:
# 418/418 [==============================] - 0s 281us/step

# %%
prediction.to_csv('Submissions/titantic_predictions_sequential_keras_1.csv',index=False)

# %% [markdown]
# ### Accuracy Scores

# %% [markdown]
# Folds = 20
#
# <br> Feature Engineering 1 - acc = 0.6018
# <br> Feature Engineering 2 - acc = 0.6434
# <br> Feature Engineering 3 - acc = 0.8133

# %% [markdown]
# ### Kaggle Results

# %% [markdown]
# <br> Feature Engineering 1 - Score: 0.65550
# <br> Feature Engineering 2 - Score: 0.69377
# <br> Feature Engineering 3 - Score: 0.7751

# %% [markdown]
# Author: Kavi Sekhon
