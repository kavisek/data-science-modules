# %%
import pandas as pd

# %%
city = pd.read_csv('Data/GlobalLandTemperaturesByCity.csv')

# %%
city.to_csv('Data/GlobalLandTemperaturesByCity.csv')
