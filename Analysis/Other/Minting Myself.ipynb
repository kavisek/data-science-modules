# %% [markdown]
# # Flow Analysis with Mint.com Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

transactions = pd.DataFrame(pd.read_csv('transactions.csv'))
transactions.dtypes
# Out:
# Date                     object
# Description              object
# Original Description     object
# Amount                  float64
# Transaction Type         object
# Category                 object
# Account Name             object
# Labels                  float64
# Notes                   float64
# dtype: object

# %%
transactions.sample(n=50)
# Out:
#             Date                 Description  \
# 3456   6/17/2015                     Gateway
# 771   12/04/2016              Browns Maple R
# 3460   6/16/2015       Tangerine Email Money
# 4082  10/23/2014                Tim Horton's
# 2104   2/23/2016      Sfu Bookstore Vancouve
# 663   12/29/2016  Purdys Chocolatier Vancouv
# 1345   7/11/2016                        Esso
# 3848   1/01/2015                  McDonald's
# 3433   6/23/2015          Sq Station Express
# 2111   2/22/2016        Electronics Boutique
# 3445   6/20/2015        Withdrawal ABM North
# 3344   7/12/2015                     Denny's
# 807   11/23/2016                    7-Eleven
# 1465   6/21/2016        Chartwellssfuraveqps
# 2737  10/31/2015               Interest Paid
# 1792   4/26/2016                      Subway
# 991   10/16/2016                  Cafe Crepe
# 129    4/20/2017    Reversal Tangerine Email
# 3751   1/20/2015                   Starbucks
# 2232   1/26/2016    Station Newstand Vancouv
# ...
