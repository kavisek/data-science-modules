# %%
# Scatter Matrix Plot
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# <img src="data:image/png;base64,..." width="600">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a27a6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a359668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a3a7940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a4200b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a47e358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a47e390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a557940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a591d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a5de780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a613780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a6ab198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a6b5e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a76df60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a7ce748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a838da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a8a0160>]], dtype=object)
