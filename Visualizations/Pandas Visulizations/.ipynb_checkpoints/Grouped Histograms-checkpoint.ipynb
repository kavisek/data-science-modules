# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
matplotlib.style.use('ggplot')

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()

df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

data = pd.Series(np.random.randn(1000))

df4.head()
# Out:
#           a         b         c
# 0  2.940803 -0.195993 -1.921167
# 1  0.563269  0.410120 -1.001542
# 2  2.150676  0.148067 -1.998329
# 3  1.255262  0.981038 -1.654196
# 4  1.145898  1.590939 -1.077468

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114119240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114ffb6a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x115012b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1150c5240>]], dtype=object)

# %%
data.head()
# Out:
# 0    1.187521
# 1    0.943131
# 2    0.543969
# 3   -1.859863
# 4    1.008714
# dtype: float64

# %%
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))
# Out:
# <img src="data:image/png;base64,..." width="600">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11554f470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115f12ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x115f87438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115fca1d0>]], dtype=object)
