# %% [markdown]
# # Calling Keras layers on TensorFlow tensors

# %%
import tensorflow as tf
sess = tf.Session()

# %% [markdown]
# https://blog.keras.io/keras-as-a-simplified-interface-to-tensorflow-tutorial.html

# %%
from keras import backend as K
K.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
# this placeholder will contain our input digits, as flat vectors
img = tf.placeholder(tf.float32, shape=(None, 784))

# %%
from keras.layers import Dense

# keras layse can be called on TensFlow tensors:
# fully - connected layer with 128 unit and relu activation
x = Dense(128, activation='relu')(img)
x = Dense (128, activation='relu')(x)
# output layer with 10 units and a softmax activation
preds = Dense(10, activation='softmax')(x)

# %%
labels = tf. placeholder(tf.float32, shape=(None, 10))

from keras.objectives import categorical_crossentropy
loss = tf.reduce_mean(categorical_crossentropy(labels, preds))

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist_data = input_data.read_data_sets('MNIST_data', one_hot=True)

train_step = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

# Intialize all variable

init_op = tf.global_variables_initializer()
sess.run(init_op)

# Run training looop
with sess.as_default():
    for i in range(100):
        batch = mnist_data.train.next_batch(50)
        train_step.run(feed_dict={img: batch[0], labels: batch[1]})
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
from keras.metrics import categorical_accuracy as accuracy

acc_value = accuracy(labels, preds)
with sess.as_default():
    print (acc_value.eval(feed_dict={img: mnist_data.test.images, 
                                     labels: mnist_data.test.labels}))
# Out:
# [ 1.  1.  1. ...,  0.  1.  1.]

# %% [markdown]
# # Diffent behaviours during training and testing

# %%
from keras import backend as K
print (K.learning_phase())
# Out:
# Tensor("keras_learning_phase:0", dtype=bool)

# %%
# train mode
train_step.run(feed_dict={x: batch[0], labels: batch[1], K.learning_phase(): 1})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-94e801e5b8e0> in <module>()
#       1 # train mode
#       2 tf.Session()
# ----> 3 train_step.run(feed_dict={x: batch[0], labels: batch[1], K.learning_phase(): 1})
#
# /Users/kavisekhon/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in run(self, feed_dict, session)
#    1550         none, the default session will be used.
#    1551     """
# -> 1552     _run_using_default_session(self, feed_dict, self.graph, session)
#    1553
#    1554
#
# /Users/kavisekhon/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _run_using_default_session(operation, feed_dict, graph, session)
#    3760     session = get_default_session()
#    3761     if session is None:
# -> 3762       raise ValueError("Cannot execute operation using `run()`: No default "
#    3763                        "session is registered. Use `with "
#    3764                        "sess.as_default():` or pass an explicit session to "
#
# ValueError: Cannot execute operation using `run()`: No default session is registered. Use `with sess.as_default():` or pass an explicit session to `run(session=sess)`

# %%
from keras.layers import Dropout
from keras import backend

img = tf.placeholder(tf.float32, shape=(None, 784))
labels = tf.placeholder(tf.float32, shape=(None, 10))

x = Dropout(128, activation='relu')(img)
x = Dropout(0.5)(x)
X = Dense(0.5)(x)
X = Dropout(0.5)(x)
preds = Dense(10, activation='softmax')(x)
loss = tf.reduce_mean(categorical_crossentropy(labels, preds))

train_step = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
with sess.as_default:
        for i in range (100):
            batch=mnist_data.train.next_batch(50)
            train_step.run(feed_dict={img: batch[0],labels: batch[1],
                                     K.learning_phase(): 1})
acc_value = accuracy(labels, preds)
with sess.as_default():
    print (acc_value.eval(feed_dict={img: mnist_data.text.images, 
                                    labels: mnist_data.test.labels, 
                                    K.learning_phase():1}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-73698eddcd33> in <module>()
#       5 labels = tf.placeholder(tf.float32, shape=(None, 10))
#       6
# ----> 7 x = Dropout(128, activation='relu')(img)
#       8 x = Dropout(0.5)(x)
#       9 X = Dense(0.5)(x)
#
# /Users/kavisekhon/anaconda/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /Users/kavisekhon/anaconda/lib/python3.6/site-packages/keras/layers/core.py in __init__(self, rate, noise_shape, seed, **kwargs)
#      92     @interfaces.legacy_dropout_support
#      93     def __init__(self, rate, noise_shape=None, seed=None, **kwargs):
# ---> 94         super(Dropout, self).__init__(**kwargs)
#      95         self.rate = min(1., max(0., rate))
#      96         self.noise_shape = noise_shape
#
# /Users/kavisekhon/anaconda/lib/python3.6/site-packages/keras/engine/topology.py in __init__(self, **kwargs)
#     279         for kwarg in kwargs:
#     280             if kwarg not in allowed_kwargs:
# --> 281                 raise TypeError('Keyword argument not understood:', kwarg)
#     282         name = kwargs.get('name')
#     283         if not name:
#
# TypeError: ('Keyword argument not understood:', 'activation')
