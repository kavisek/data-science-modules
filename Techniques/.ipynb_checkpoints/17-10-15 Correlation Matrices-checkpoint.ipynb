# %% [markdown]
# # Correlation Matrices
#
# <span>Pandas has this great dataframe correlation function that can operate on the entire dataframe. The function support Pearson, Kendall, and Spearman correlations. You can use this function with seaborn to create a heat map to view the data at a glance. For prettier correlation plots you can always just use seaborn but you will not be able to extract the model variables from Seaborn. In that case, there is always Scikit Learn and Scipy for the gritty numbers if you need them.</span>
#
# ### Import Preliminaries

# %%
# Import Modules
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from sklearn.datasets import load_iris

iris = load_iris()
data = iris.data
df = pd.DataFrame(data)
df.columns = iris['feature_names']
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9                 3                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                  5               3.6                1.4               0.2

# %% [markdown]
# ### Pearson Correlation

# %%
# view default correlation which is pearson
df.corr(method='pearson')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)                  1             -0.11               0.87
# sepal width (cm)               -0.11                 1              -0.42
# petal length (cm)               0.87             -0.42                  1
# petal width (cm)                0.82             -0.36               0.96
#
#                    petal width (cm)
# sepal length (cm)              0.82
# sepal width (cm)              -0.36
# petal length (cm)              0.96
# petal width (cm)                  1

# %% [markdown]
# ### Kendall Correlation

# %%
df.corr(method='kendall')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)                  1            -0.072               0.72
# sepal width (cm)              -0.072                 1              -0.18
# petal length (cm)               0.72             -0.18                  1
# petal width (cm)                0.65             -0.15                0.8
#
#                    petal width (cm)
# sepal length (cm)              0.65
# sepal width (cm)              -0.15
# petal length (cm)               0.8
# petal width (cm)                  1

# %% [markdown]
# ### Spearman Correlation

# %%
df.corr(method='spearman')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)                  1             -0.16               0.88
# sepal width (cm)               -0.16                 1               -0.3
# petal length (cm)               0.88              -0.3                  1
# petal width (cm)                0.83             -0.28               0.94
#
#                    petal width (cm)
# sepal length (cm)              0.83
# sepal width (cm)              -0.28
# petal length (cm)              0.94
# petal width (cm)                  1

# %% [markdown]
# ### P-Value Matrix

# %%
# Create a datfarme to store p-values
fnum = df.shape[1]
pvalues = np.zeros((fnum, fnum))
pvalues = pd.DataFrame(pvalues)

# Calculating all the pvalues for our corrlation
for i, col1 in zip(range(fnum),df):
    for j, col2 in zip(range(fnum),df):
        pvalues.iloc[i,j] = scipy.stats.pearsonr(df[col1],df[col2])[1]

# Display results in scientific notation
pd.set_option('display.float_format', '{:.2g}'.format)

pvalues.columns, pvalues.index = df.columns, df.columns
pvalues
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)                  0              0.18              1e-47
# sepal width (cm)                0.18                 0            8.4e-08
# petal length (cm)              1e-47           8.4e-08                  0
# petal width (cm)             2.3e-37           7.5e-06            5.8e-86
#
#                    petal width (cm)
# sepal length (cm)           2.3e-37
# sepal width (cm)            7.5e-06
# petal length (cm)           5.8e-86
# petal width (cm)                  0

# %% [markdown]
# ### Correlation Heatmap
#
# This plot uses a spearman correlation

# %%
sns.heatmap(df.corr(method='spearman'))

# %% [markdown]
# ### Seaborn Joinplot Visualization

# %%
import warnings
warnings.filterwarnings("ignore") # Remove Package Warning

sns.jointplot(x=df['sepal length (cm)'], y=df['sepal width (cm)'], data=df);

# %% [markdown]
# ### Seaborn DataFrame Correlation Matrix

# %%
sns.pairplot(df);

# %% [markdown]
# Author: Kavi Sekhon
