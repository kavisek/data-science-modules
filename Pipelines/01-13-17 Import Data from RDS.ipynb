# %% [markdown]
# # <center> Importing Data from RDS
# ### Import Prelimnaries

# %%
# import pymysql and pandas information
import pandas as pd
import pymysql

# setting up db  connection parameters 
host="aws.endpoint.us-east-2.rds.amazonaws.com"
port=3306
db ='world'
user="Username"
password="Password"

# Set up the connection
conn = pymysql.connect(db=db, host=host, user=user,port=port, 
                       passwd=password)

# %% [markdown]
# ### Import and Query the Data

# %%
# read sql data with pandas
df = pd.read_sql('SELECT * from country;',con=conn)

# view the dataframe
df.sample(5)
# Out:
#     Code           Name      Continent            Region  SurfaceArea  \
# 94   HND       Honduras  North America   Central America     112088.0
# 73   FRO  Faroe Islands         Europe  Nordic Countries       1399.0
# 216  TUV         Tuvalu        Oceania         Polynesia         26.0
# 122  LCA    Saint Lucia  North America         Caribbean        622.0
# 85   GRC         Greece         Europe   Southern Europe     131626.0
#
#      IndepYear  Population  LifeExpectancy       GNP    GNPOld    LocalName  \
# 94      1838.0     6485000            69.9    5333.0    4697.0     Honduras
# 73         NaN       43000            78.4       0.0       NaN     FÃ¸royar
# 216     1978.0       12000            66.3       6.0       NaN       Tuvalu
# 122     1979.0      154000            72.3     571.0       NaN  Saint Lucia
# 85      1830.0    10545700            78.4  120724.0  119946.0      EllÃ¡da
#
#               GovernmentForm                     HeadOfState  Capital Code2
# ...

# %% [markdown]
# Author: Kavi
