# %% [markdown]
# # <center> Importing Data from RDS
# Source: http://datascience-enthusiast.com/R/AWS_RDS_R_Python.html

# %%
# import pymysql and pandas information
import pandas as pd
import pymysql

# setting up db  connection parameters 
host="forrpython.cab6rvva6lca.us-east-1.rds.amazonaws.com"
port=3306
user="your_username"
password="your_password"

conn = pymysql.connect(host, user=user,port=port, 
                       passwd=password)

# %%
# read sql data with pandas
df = pd.read_sql('SELECT * from country;',con=conn)
df.sample(5)
# Out:
#     Code               Name Continent           Region  SurfaceArea  \
# 214  TUN            Tunisia    Africa  Northern Africa     163610.0
# 178  QAT              Qatar      Asia      Middle East      11000.0
# 232  WLF  Wallis and Futuna   Oceania        Polynesia        200.0
# 32   BRN             Brunei      Asia   Southeast Asia       5765.0
# 120  LBR            Liberia    Africa   Western Africa     111369.0
#
#      IndepYear  Population  LifeExpectancy      GNP   GNPOld  \
# 214     1956.0     9586000            73.7  20026.0  18898.0
# 178     1971.0      599000            72.4   9472.0   8920.0
# 232        NaN       15000             NaN      0.0      NaN
# 32      1984.0      328000            73.6  11705.0  12460.0
# 120     1847.0     3154000            51.0   2012.0      NaN
#
#              LocalName                       GovernmentForm  \
# 214      Tunis/Tunisie                             Republic
# 178              Qatar                             Monarchy
# 232   Wallis-et-Futuna  Nonmetropolitan Territory of France
# 32   Brunei Darussalam                 Monarchy (Sultanate)
# 120            Liberia                             Republic
#
#                     HeadOfState  Capital Code2
# 214     Zine al-Abidine Ben Ali   3349.0    TN
# 178  Hamad ibn Khalifa al-Thani   2973.0    QA
# 232              Jacques Chirac   3536.0    WF
# 32       Haji Hassan al-Bolkiah    538.0    BN
# 120              Charles Taylor   2440.0    LR
