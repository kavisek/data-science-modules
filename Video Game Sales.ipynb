# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy as scp
import matplotlib
import matplotlib.pyplot as plt

#pd.set_option('html', False)

v = pd.read_csv('/Users/Data_Freak/Desktop/vgsales.csv')
v
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# ...

# %%
v.Year = v.Year.astype(int)
v
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-16d360583d45> in <module>()
# ----> 1 v.Year = v.Year.astype(int)
#       2 v
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2948
#    2949         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2950                                 raise_on_error=raise_on_error, **kwargs)
#    2951         return self._constructor(mgr).__finalize__(self)
#    2952
#
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    2936
#    2937     def astype(self, dtype, **kwargs):
# -> 2938         return self.apply('astype', dtype=dtype, **kwargs)
#    2939
#    2940     def convert(self, **kwargs):
#
# ...

# %%
v.count()

# %%
v.mean()

# %%
v.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dc6224112d8c> in <module>()
# ----> 1 vdf.describe()
#
# NameError: name 'vdf' is not defined

# %%
v.std()
# Out:
# Rank            4791.853933
# Year               5.828981
# NA_Sales           0.816683
# EU_Sales           0.505351
# JP_Sales           0.309291
# Other_Sales        0.188588
# Global_Sales       1.555028
# dtype: float64

# %%
v.var()
# Out:
# Rank            2.296186e+07
# Year            3.397702e+01
# NA_Sales        6.669712e-01
# EU_Sales        2.553799e-01
# JP_Sales        9.566070e-02
# Other_Sales     3.556559e-02
# Global_Sales    2.418112e+00
# dtype: float64

# %%
v.median()
# Out:
# Rank            8300.50
# Year            2007.00
# NA_Sales           0.08
# EU_Sales           0.02
# JP_Sales           0.00
# Other_Sales        0.01
# Global_Sales       0.17
# dtype: float64

# %%
v['NA_Sales'].max()
# Out:
# 41.490000000000002

# %%
#Line Graph using 
plt.plot(v['Global_Sales'],v['NA_Sales'])
plt.ylabel ("North American Sales")
plt.xlabel('Global Salse')
plt.show()

# %%
#Line Graph with Matplotlib
plt.plot(v['Global_Sales'],v['NA_Sales'], 'r--', linewidth=0.5)
plt.ylabel ("North American Sales")
plt.xlabel('Global Salse')
plt.grid(True)
plt.show()

# %%
#Scatterplot with Matplotlib
plt.plot(v['Global_Sales'],v['NA_Sales'],'ro')
plt.xlabel ("North American Sales")
plt.ylabel('Global Salse')
plt.show()

# %%
#This is Sample Code from Matplotlib.org (http://matplotlib.org/users/pyplot_tutorial.html)

import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
#Creating a Histogram using Numpy

n, bins, patches = plt.hist(v["Global_Sales"])
plt.title('Histogram of Global Sales')
plt.xlabel('Sales')
plt.ylabel('Year')
plt.grid(True)
plt.show()
